# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/data'

# %%
train_sliced = h5py.File(data_path + '/train_sliced_images_from_0_to_5.hdf5', 'r')
train_sliced = train_sliced['sliced_images_train']

# %%
train_masked_sliced_data = h5py.File(data_path + '/train_masked_sliced_images_from_0_to_5.hdf5', 'r')
train_masked_sliced = train_masked_sliced_data['sliced_images_train']

# %%
extended_train_masked_sliced_data = h5py.File(data_path + '/train_masked_sliced_images_from_0_to_5.hdf5', 'r')
extended_train_masked_sliced = extended_train_masked_sliced_data['sliced_images_train']

# %%
n = 0

# %%
fig, axs = plt.subplots(8,8, figsize=(14,14))
ax = axs.ravel()
for i in range(64):
    ax[i].imshow(train_masked_sliced[i+ (n*64), :,:, 18,0], cmap='gray')
    #ax[i].set_title(i)
    ax[i].axis('off')

# %%
plt.imshow(train_masked_sliced[i+ (n*64), :,:, 18,0], cmap='gray')
plt.colorbar()

# %%
fig, axs = plt.subplots(8,8, figsize=(14,14))
ax = axs.ravel()
for i in range(64):
    ax[i].imshow(extended_train_masked_sliced[i+ (n*64), :,:, 19,0])
    #ax[i].set_title(i)
    ax[i].axis('off')

# %%
fig, axs = plt.subplots(8,8, figsize=(14,14))
ax = axs.ravel()
for i in range(64):
    ax[i].imshow(train_sliced[i+ (n*64), :,:, 3,1])
    #ax[i].set_title(i)
    ax[i].axis('off')
