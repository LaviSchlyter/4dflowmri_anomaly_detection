# %%
import os
import numpy as np 

import sys


sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "helpers"))

# Helpers
from utils import verify_leakage ,crop_or_pad_Bern_slices, normalize_image, normalize_image_new, make_dir_safely, crop_or_pad_normal_slices

from data_bern_numpy_to_preprocessed_hdf5 import interpolate_and_slice, rotate_vectors, skeleton_points, order_points

from skimage.morphology import skeletonize_3d, dilation, cube, binary_erosion

# %%
import numpy as np
CS_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_206_anomaly_scores.npy')
Seq_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_206_anomaly_scores.npy')

print(np.argmax(np.mean(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.mean(Seq_version, axis=(0, 1, 2, 3))))
# same but with max
print(np.argmax(np.max(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.max(Seq_version, axis=(0, 1, 2, 3))))
# Out:
# ((64, 1, 32, 32, 24), (64, 1, 32, 32, 24))

# %%
import numpy as np
CS_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_135_anomaly_scores.npy')
Seq_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_135_anomaly_scores.npy')

print(np.argmax(np.mean(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.mean(Seq_version, axis=(0, 1, 2, 3))))
# same but with max
print(np.argmax(np.max(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.max(Seq_version, axis=(0, 1, 2, 3))))
# Out:
# 8
# 8
# 16
# 16

# %%
import numpy as np
CS_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_133_anomaly_scores.npy')
Seq_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_133_anomaly_scores.npy')

print(np.argmax(np.mean(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.mean(Seq_version, axis=(0, 1, 2, 3))))
# same but with max
print(np.argmax(np.max(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.max(Seq_version, axis=(0, 1, 2, 3))))
# Out:
# 8
# 8
# 16
# 16

# %%
import numpy as np
CS_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_206_anomaly_scores.npy')
Seq_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_206_anomaly_scores.npy')

print(np.argmax(np.mean(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.mean(Seq_version, axis=(0, 1, 2, 3))))
# same but with max
print(np.argmax(np.max(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.max(Seq_version, axis=(0, 1, 2, 3))))
# Out:
# 11
# 11
# 11
# 11

# %%
import numpy as np
CS_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_131_anomaly_scores.npy')
Seq_version = np.load('/usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/Results/Evaluation/vae_convT/masked_slice/20240518-2136_vae_convT_masked_slice_SSL_lr1.000e-03-e1500-bs8-gf_dim8-daFalse__SEED_5_2Dslice__without_rotation_with_cs_skip_updated_ao_S10_balanced_decreased_interpolation_factor_cube_3/test/outputs/MACDAVD_131_anomaly_scores.npy')

print(np.argmax(np.mean(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.mean(Seq_version, axis=(0, 1, 2, 3))))
# same but with max
print(np.argmax(np.max(CS_version, axis=(0, 1, 2, 3))))
print(np.argmax(np.max(Seq_version, axis=(0, 1, 2, 3))))
# Out:
# 8
# 8
# 11
# 11

# %%
common_image_shape = [36, 36, 64, 24, 4] # [x, y, z, t, num_channels]
end_shape = [32, 32, 64, 24, 4]


seg_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/segmenter_rw_pw_hard/controls_compressed_sensing/seg_MACDAVD_146.npy'

img_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/preprocessed/controls/numpy_compressed_sensing/MACDAVD_146.npy'

seg_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/segmenter_rw_pw_hard/controls/seg_MACDAVD_146_.npy'

img_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/preprocessed/controls/numpy/MACDAVD_146_.npy'

seg_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/segmenter_rw_pw_hard/patients_compressed_sensing/seg_MACDAVD_206.npy'

img_path = '/usr/bmicnas02/data-biwi-01/jeremy_students/data/inselspital/kady/preprocessed/patients/numpy_compressed_sensing/MACDAVD_206.npy'

segmented_original = np.load(seg_path)

image= np.load(img_path)

# Enlarge the segmentation slightly to be sure that there are no cutoffs of the aorta
time_steps = segmented_original.shape[3]
#segmented = dilation(segmented_original[:,:,:,3], cube(6))
segmented = dilation(segmented_original[:,:,:,3], cube(3))

temp_for_stack = [segmented for i in range(time_steps)]
segmented = np.stack(temp_for_stack, axis=3)

image = image.astype(float)

temp_images_intensity = image[:,:,:,:,0] * segmented # change these back if it works
temp_images_vx = image[:,:,:,:,1] * segmented
temp_images_vy = image[:,:,:,:,2] * segmented
temp_images_vz = image[:,:,:,:,3] * segmented

# recombine the images
image = np.stack([temp_images_intensity,temp_images_vx,temp_images_vy,temp_images_vz], axis=4)
updated_ao = True

points = skeleton_points(segmented_original, dilation_k = 2,erosion_k = 2)

if updated_ao:
    try:
    
        points_order_ascending_aorta = order_points(points[::-1], angle_threshold=3/2*np.pi/2.)
        print('points order ascending aorta with angle threshold 3/2*np.pi/2.')
    except Exception as e:
        try:
            points_order_ascending_aorta = order_points(points[::-1], angle_threshold=1/2*np.pi/2.)
            print('points order ascending aorta with angle threshold 1/2*np.pi/2.')
        except Exception as e:
            points_order_ascending_aorta = np.array([0,0,0])
            
    
    points = points[(points[:, 0] <= 90) & (points[:, 0] >= points_order_ascending_aorta[0][0]) & (points[:, 1] <= points_order_ascending_aorta[0][1])]

else:
    points = points[np.where(points[:,1]<65)]
    points = points[np.where(points[:,0]<90)]
    points = points[points[:,0].argsort()[::-1]]


temp = []
#for index, element in enumerate(points):
for index, element in enumerate(points[2:]):
    if (index%2)==0:
        temp.append(element)

coords = np.array(temp)
temp_for_channel_stacking = []
for channel in range(image.shape[4]):

    temp_for_time_stacking = []
    for t in range(image.shape[3]):
        
        
        slice_dict = interpolate_and_slice(image[:,:,:,t,channel], coords, common_image_shape, smoothness=10)
        
        straightened = slice_dict['straightened']

        temp_for_time_stacking.append(straightened)

    channel_stacked = np.stack(temp_for_time_stacking, axis=-1)
    temp_for_channel_stacking.append(channel_stacked)

straightened = np.stack(temp_for_channel_stacking, axis=-1)

image_out = crop_or_pad_normal_slices(straightened, end_shape)

# Use seg,emtatation mask to cover image_out
# Out:
# /usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/helpers/data_bern_numpy_to_preprocessed_hdf5.py:202: FutureWarning: `selem` is a deprecated argument name for `binary_erosion`. It will be removed in version 1.0. Please use `footprint` instead.
#   avg = binary_erosion(avg, selem=np.ones((erosion_k, erosion_k,erosion_k)))
# /usr/bmicnas02/data-biwi-01/jeremy_students/lschlyter/4dflowmri_anomaly_detection/helpers/data_bern_numpy_to_preprocessed_hdf5.py:203: FutureWarning: `selem` is a deprecated argument name for `dilation`. It will be removed in version 1.0. Please use `footprint` instead.
#   avg = dilation(avg, selem=np.ones((dilation_k, dilation_k,dilation_k)))
# points order ascending aorta with angle threshold 3/2*np.pi/2.

# %%
# Plot the 64 slices of the image_out and decide which time step and channel

time_step = 0
channel = 1

import matplotlib.pyplot as plt

fig, axs = plt.subplots(8,8, figsize=(20,20))
for i in range(64):
    axs[i//8, i%8].imshow(image_out[:,:,i,time_step,channel])
    axs[i//8, i%8].axis('off')
    # add colorbar

# %%
# Plot the 64 slices of the image_out and decide which time step and channel

time_step = 0
channel = 1

import matplotlib.pyplot as plt

fig, axs = plt.subplots(8,8, figsize=(20,20))
for i in range(64):
    axs[i//8, i%8].imshow(image_out[:,:,i,time_step,channel])
    axs[i//8, i%8].axis('off')
    # add colorbar

# %%
# Plot the 64 slices of the image_out and decide which time step and channel

time_step = 0
channel = 1

import matplotlib.pyplot as plt

fig, axs = plt.subplots(8,8, figsize=(20,20))
for i in range(64):
    axs[i//8, i%8].imshow(image_out[:,:,i,time_step,channel])
    axs[i//8, i%8].axis('off')
    # add colorbar

# %%
# Plot the 64 slices of the image_out and decide which time step and channel

time_step = 5
channel = 1

import matplotlib.pyplot as plt

fig, axs = plt.subplots(8,8, figsize=(20,20))
for i in range(64):
    axs[i//8, i%8].imshow(image_out[:,:,i,time_step,channel])
    axs[i//8, i%8].axis('off')
